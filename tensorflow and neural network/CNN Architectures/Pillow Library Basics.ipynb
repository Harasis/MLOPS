# %%
from PIL import Image

# %%
im = Image.open('Chihuahua-longhaired-sitting-its-head-tilted.jpg')

# %%
type(im)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
im.show()

# %%
im.crop((50,50,400,400))  #((x1,y1,x2,y2))
# Out:
# <PIL.Image.Image image mode=RGB size=350x350 at 0x219A672A8C8>

# %%
im.rotate(45)
# Out:
# <PIL.Image.Image image mode=RGB size=729x486 at 0x219A6744E08>

# %%
im1=im. resize((100,100))
im1
# Out:
# <PIL.Image.Image image mode=RGB size=100x100 at 0x219A58328C8>

# %%
im1.transpose(Image.ROTATE_90)
# Out:
# <PIL.Image.Image image mode=RGB size=100x100 at 0x219A58327C8>

# %%
Image.ROTATE_90
# Out:
# 2

# %%
im1.transpose(2)
# Out:
# <PIL.Image.Image image mode=RGB size=100x100 at 0x219A63B40C8>

# %%
im1.height
# Out:
# 100

# %%
im1.width
# Out:
# 100

# %%
im1.format

# %%
im1.save("new.jpg")
